# %%
import numpy 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
seaborn.set_style("white")

# permet d'afficher les graphiques dans un notebook
# %matplotlib inline

# %%
# le dropna() permet de supprimer les pays pour lesquels il manque des informations
data_vdt = pd.read_csv("DataVdt_N.csv", sep = ";")
data_vdt
# Out:
#            Code Habitat  Age  Surface  Buchholzia  Buchholzia fallax  \
# 0    CpUt_35Aqu    CpUt    1   147.15           0                  0
# 1    EvEx_15Aqu    EvEx    1   159.16           0                  0
# 2    CpPl_01Bou    CpPl    3    37.30           0                  0
# 3    CpPl_02Bou    CpPl    3    45.70           0                  0
# 4    CpPl_03Bou    CpPl    3   104.90           0                  0
# ..          ...     ...  ...      ...         ...                ...
# 128  CpPl_06Vol    CpPl    3    68.00           0                  0
# 129  CpPl_07Vol    CpPl    3    96.45           0                  0
# 130  CpUt_06Vol    CpUt    3   157.00           0                  0
# 131  CpUt_07Vol    CpUt    3   181.00           0                  0
# 132  CpUt_08Vol    CpUt    3    50.00           0                  0
#
#      Enchytraeidae  Enchytraeus  Enchytraeus japonensis  \
# 0                1            1                       0
# ...

# %%
data_vdt['Total_VDT'] = data_vdt.iloc[:, -36:].sum(axis=1)

# %%
# Out:
#            Code Habitat  Age  Surface  Buchholzia  Buchholzia fallax  \
# 0    CpUt_35Aqu    CpUt    1   147.15           0                  0
# 1    EvEx_15Aqu    EvEx    1   159.16           0                  0
# 2    CpPl_01Bou    CpPl    3    37.30           0                  0
# 3    CpPl_02Bou    CpPl    3    45.70           0                  0
# 4    CpPl_03Bou    CpPl    3   104.90           0                  0
# ..          ...     ...  ...      ...         ...                ...
# 128  CpPl_06Vol    CpPl    3    68.00           0                  0
# 129  CpPl_07Vol    CpPl    3    96.45           0                  0
# 130  CpUt_06Vol    CpUt    3   157.00           0                  0
# 131  CpUt_07Vol    CpUt    3   181.00           0                  0
# 132  CpUt_08Vol    CpUt    3    50.00           0                  0
#
#      Enchytraeidae  Enchytraeus  Enchytraeus japonensis  \
# 0                1            1                       0
# ...

# %%
data_vdt.describe()
# Out:
#               Age     Surface  Buchholzia  Buchholzia fallax  Enchytraeidae  \
# count  133.000000  132.000000  133.000000         133.000000     133.000000
# mean     1.857143   80.168788    0.007519           0.015038       0.744361
# std      0.697863   78.114387    0.086711           0.122162       0.437869
# min      1.000000    9.100000    0.000000           0.000000       0.000000
# 25%      1.000000   26.550000    0.000000           0.000000       0.000000
# 50%      2.000000   51.100000    0.000000           0.000000       1.000000
# 75%      2.000000  105.517500    0.000000           0.000000       1.000000
# max      3.000000  425.810000    1.000000           1.000000       1.000000
#
#        Enchytraeus  Enchytraeus japonensis  Enchytraeus luxuriosus  \
# count   133.000000              133.000000              133.000000
# mean      0.067669                0.067669                0.015038
# std       0.252127                0.252127                0.122162
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Fichier TableauxdonnéesParcelle.xlsx
# ## Première exploration des données

# %%
data_parcelle = pd.read_excel('../Donnees/TableauxdonnéesParcelle.xlsx')
data_parcelle.head()
# Out:
#        Ecole   Age Habitat    Parcelle  Nb arbres  Temps  Ganivelles  \
# 0  Boulloche  2021    CpPl  CpPl_01Bou          1      3           0
# 1  Boulloche  2021    CpPl  CpPl_02Bou          0      3           0
# 2  Boulloche  2021    CpPl  CpPl_03Bou          4      3           0
# 3   Voltaire  2021    CpPl  CpPl_04Vol          1      3           0
# 4   Voltaire  2021    CpPl  CpPl_05Vol          0      3           0
#
#    Emplacement  Enfantsparm2  Surface
# 0            0          11.6     37.3
# 1            1          11.6     45.7
# 2            0          11.6    104.9
# 3            1          10.7     44.3
# 4            1          10.7    225.3

# %%
data_parcelle.dtypes #on regarde les types de données
# Out:
# Ecole            object
# Age               int64
# Habitat          object
# Parcelle         object
# Nb arbres         int64
# Temps             int64
# Ganivelles        int64
# Emplacement       int64
# Enfantsparm2    float64
# Surface         float64
# dtype: object

# %%
data_parcelle.describe() #on regarde les statistiques descriptives
# Out:
#                Age   Nb arbres       Temps  Ganivelles  Emplacement  \
# count   127.000000  127.000000  127.000000  127.000000   127.000000
# mean   2022.141732    1.937008    1.858268    0.330709     0.480315
# std       0.709621    2.053831    0.709621    0.472332     0.501591
# min    2021.000000    0.000000    1.000000    0.000000     0.000000
# 25%    2022.000000    1.000000    1.000000    0.000000     0.000000
# 50%    2022.000000    1.000000    2.000000    0.000000     0.000000
# 75%    2023.000000    3.000000    2.000000    1.000000     1.000000
# max    2023.000000   13.000000    3.000000    1.000000     1.000000
#
#        Enfantsparm2     Surface
# count    127.000000  127.000000
# mean      13.005512   79.145039
# std        8.846857   78.443645
# min        4.000000    9.100000
# 25%        7.500000   25.150000
# 50%       11.400000   50.000000
# 75%       14.500000  104.250000
# max       41.900000  425.810000

# %% [markdown]
# Le tableau précédent montre les statistiques descriptives des variables du fichier excel
# Il faut ignorer la colonne Age qui réalise une étude statistique sur des années, ce qui n'est pas pertinent, on étudiera plutot la colonne temps pour les durées d'installation des parcelles.
# Ganivelles et Emplacement sont codées en binaire respectivement pour la présence (ou non) de ganivelles autour des parcelles et la position au bord (ou non) de la parcelle dans la cour.
